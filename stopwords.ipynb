# %% [markdown]
# ### Stopwords: These are the common words which have very little useful meaning.
# examples: a, an, the, am, but, or, because, are, was, were, be

# %%
from nltk.stem import PorterStemmer
# importing stopwords from nltk library
from nltk.corpus import stopwords

# %%
# Importing nltk library 
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\defaultuser0\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
### To see the list of stopwords in various languages: 
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
## A small corpus on AI
paragraph = "Artificial Intelligence is rapidly changing the world of cybersecurity. It helps analysts detect threats faster, but hackers are also using AI to create sophisticated attacks. We must build stronger defenses to protect our data from these evolving dangers."

# %%
from nltk.stem import PorterStemmer
Stemmer = PorterStemmer()

sentences = nltk.sent_tokenize(paragraph)
print(sentences)
# Out:
# ['Artificial Intelligence is rapidly changing the world of cybersecurity.', 'It helps analysts detect threats faster, but hackers are also using AI to create sophisticated attacks.', 'We must build stronger defenses to protect our data from these evolving dangers.']

# %%
# Applying stopwords and filter and then apply stemming. 
""" 1. First converting sentences into words
    2. Secondly, Filtering them by removing stopwords
    3. Then again joining them into sentences."""
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
from nltk.corpus import stopwords

for i in range(len(sentences)): # Looping through the sentences
    words = nltk.word_tokenize(sentences[i]) # Converting sentences into words
    words = [stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    sentences[i] = ' '.join(words)

# %%
# Printing the sentences
sentences
# Out:
# ['artifici intellig rapidli chang world cybersecur .',
#  'it help analyst detect threat faster , hacker also use ai creat sophist attack .',
#  'we must build stronger defens protect data evolv danger .']
